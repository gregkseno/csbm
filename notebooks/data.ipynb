# %%
# %load_ext autoreload
# %autoreload 2
import sys 
sys.path.append('../src/')

import torch
from dasbm.data import DiscreteGaussianSampler, DiscreteSwissRollSampler, MoleculeDatasetSampler
import matplotlib.pyplot as plt

from rdkit import Chem
from rdkit.Chem import Crippen
import networkx as nx
import pandas as pd
import numpy as np
from scipy import stats
import torch_geometric
from tqdm.auto import tqdm
tqdm.pandas()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Toy data

# %%
sr_sampler = DiscreteSwissRollSampler(noise=0.8, num_categories=50)
sr_samples = sr_sampler.sample(1024)

# %%
plt.scatter(sr_samples[:, 0], sr_samples[:, 1])
plt.show()

# %%
g_sampler = DiscreteGaussianSampler(dim=2, num_categories=50)
g_samples = g_sampler.sample(1024)

# %%
plt.scatter(g_samples[:, 0], g_samples[:, 1])
plt.show()

# %% [markdown]
# # Graph data (FreeSolv)

# %%
dataset = torch_geometric.datasets.MoleculeNet(root='../data/', name='FreeSolv')

# %%
sampler = MoleculeDatasetSampler(dataset)
for i in tqdm(range(100)):
    sampler.sample(64)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# DataMoleculeBatch(x=[522, 9], edge_index=[2, 984], edge_attr=[984, 3], smiles=[64], y=[64, 1], batch=[522], ptr=[65])
# DataMoleculeBatch(x=[535, 9], edge_index=[2, 1026], edge_attr=[1026, 3], smiles=[64], y=[64, 1], batch=[535], ptr=[65])
# DataMoleculeBatch(x=[564, 9], edge_index=[2, 1098], edge_attr=[1098, 3], smiles=[64], y=[64, 1], batch=[564], ptr=[65])
# DataMoleculeBatch(x=[561, 9], edge_index=[2, 1088], edge_attr=[1088, 3], smiles=[64], y=[64, 1], batch=[561], ptr=[65])
# DataMoleculeBatch(x=[523, 9], edge_index=[2, 990], edge_attr=[990, 3], smiles=[64], y=[64, 1], batch=[523], ptr=[65])
# DataMoleculeBatch(x=[522, 9], edge_index=[2, 1006], edge_attr=[1006, 3], smiles=[64], y=[64, 1], batch=[522], ptr=[65])
# DataMoleculeBatch(x=[651, 9], edge_index=[2, 1284], edge_attr=[1284, 3], smiles=[64], y=[64, 1], batch=[651], ptr=[65])
# ...
